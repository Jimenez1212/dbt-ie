# %%
import duckdb

# Connect to the database (relative path from notebooks/ directory)
con = duckdb.connect("../my_database.duckdb")

# we will use .pl() to display query results as polars dataframes

# %%
# Show all tables in the main schema
con.sql("SHOW TABLES").pl()
# Out:
# shape: (14, 1)
# ┌────────────────────┐
# │ name               │
# │ ---                │
# │ str                │
# ╞════════════════════╡
# │ categories         │
# │ customer_addresses │
# │ customers          │
# │ inventory          │
# │ …                  │
# │ reviews            │
# │ shipping           │
# │ suppliers          │
# │ website_sessions   │
# └────────────────────┘

# %%
# Describe a specific table (replace 'table_name' with a real table from the list above)
con.sql("DESCRIBE customers").pl()
# Out:
# shape: (15, 6)
# ┌──────────────────┬─────────────┬──────┬──────┬─────────┬───────┐
# │ column_name      ┆ column_type ┆ null ┆ key  ┆ default ┆ extra │
# │ ---              ┆ ---         ┆ ---  ┆ ---  ┆ ---     ┆ ---   │
# │ str              ┆ str         ┆ str  ┆ str  ┆ str     ┆ i32   │
# ╞══════════════════╪═════════════╪══════╪══════╪═════════╪═══════╡
# │ customer_id      ┆ BIGINT      ┆ YES  ┆ null ┆ null    ┆ null  │
# │ first_name       ┆ VARCHAR     ┆ YES  ┆ null ┆ null    ┆ null  │
# │ last_name        ┆ VARCHAR     ┆ YES  ┆ null ┆ null    ┆ null  │
# │ email            ┆ VARCHAR     ┆ YES  ┆ null ┆ null    ┆ null  │
# │ …                ┆ …           ┆ …    ┆ …    ┆ …       ┆ …     │
# │ customer_segment ┆ VARCHAR     ┆ YES  ┆ null ┆ null    ┆ null  │
# │ total_spent      ┆ DOUBLE      ┆ YES  ┆ null ┆ null    ┆ null  │
# │ is_active        ┆ BOOLEAN     ┆ YES  ┆ null ┆ null    ┆ null  │
# │ total_orders     ┆ BIGINT      ┆ YES  ┆ null ┆ null    ┆ null  │
# └──────────────────┴─────────────┴──────┴──────┴─────────┴───────┘

# %%
# Sample data from a table
con.sql("SELECT * FROM customers LIMIT 10").pl()
# Out:
# shape: (10, 15)
# ┌───────────┬──────────┬───────────┬───────────┬───┬────────────┬────────────┬───────────┬─────────┐
# │ customer_ ┆ first_na ┆ last_name ┆ email     ┆ … ┆ customer_s ┆ total_orde ┆ total_spe ┆ is_acti │
# │ id        ┆ me       ┆ ---       ┆ ---       ┆   ┆ egment     ┆ rs         ┆ nt        ┆ ve      │
# │ ---       ┆ ---      ┆ str       ┆ str       ┆   ┆ ---        ┆ ---        ┆ ---       ┆ ---     │
# │ i64       ┆ str      ┆           ┆           ┆   ┆ str        ┆ i64        ┆ f64       ┆ bool    │
# ╞═══════════╪══════════╪═══════════╪═══════════╪═══╪════════════╪════════════╪═══════════╪═════════╡
# │ 1         ┆ First_1  ┆ Last_1    ┆ customer_ ┆ … ┆ Bronze     ┆ 5          ┆ 1531.82   ┆ true    │
# │           ┆          ┆           ┆ 1@example ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ .com      ┆   ┆            ┆            ┆           ┆         │
# │ 2         ┆ First_2  ┆ Last_2    ┆ customer_ ┆ … ┆ Silver     ┆ 5          ┆ 1636.95   ┆ true    │
# │           ┆          ┆           ┆ 2@example ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ .com      ┆   ┆            ┆            ┆           ┆         │
# │ 3         ┆ First_3  ┆ Last_3    ┆ customer_ ┆ … ┆ Bronze     ┆ 1          ┆ 150.73    ┆ true    │
# │           ┆          ┆           ┆ 3@example ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ .com      ┆   ┆            ┆            ┆           ┆         │
# │ 4         ┆ First_4  ┆ Last_4    ┆ customer_ ┆ … ┆ Silver     ┆ 8          ┆ 2114.93   ┆ true    │
# │           ┆          ┆           ┆ 4@example ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ .com      ┆   ┆            ┆            ┆           ┆         │
# │ …         ┆ …        ┆ …         ┆ …         ┆ … ┆ …          ┆ …          ┆ …         ┆ …       │
# │ 7         ┆ First_7  ┆ Last_7    ┆ customer_ ┆ … ┆ Bronze     ┆ 1          ┆ 127.61    ┆ true    │
# │           ┆          ┆           ┆ 7@example ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ .com      ┆   ┆            ┆            ┆           ┆         │
# │ 8         ┆ First_8  ┆ Last_8    ┆ customer_ ┆ … ┆ Bronze     ┆ 3          ┆ 288.27    ┆ true    │
# │           ┆          ┆           ┆ 8@example ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ .com      ┆   ┆            ┆            ┆           ┆         │
# │ 9         ┆ First_9  ┆ Last_9    ┆ customer_ ┆ … ┆ Bronze     ┆ 0          ┆ 0.0       ┆ true    │
# │           ┆          ┆           ┆ 9@example ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ .com      ┆   ┆            ┆            ┆           ┆         │
# │ 10        ┆ First_10 ┆ Last_10   ┆ customer_ ┆ … ┆ Gold       ┆ 5          ┆ 1999.83   ┆ true    │
# │           ┆          ┆           ┆ 10@exampl ┆   ┆            ┆            ┆           ┆         │
# │           ┆          ┆           ┆ e.com     ┆   ┆            ┆            ┆           ┆         │
# └───────────┴──────────┴───────────┴───────────┴───┴────────────┴────────────┴───────────┴─────────┘

# %%
# Query information_schema to see columns information for a specific table
# Using .pl() to convert to a Polars DataFrame allows you to scroll and see all columns
con.sql("SELECT * FROM information_schema.columns WHERE table_name = 'customers'").pl()
# Out:
# shape: (15, 44)
# ┌────────────┬────────────┬──────────┬───────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ table_cata ┆ table_sche ┆ table_na ┆ column_na ┆ … ┆ identity_c ┆ is_generat ┆ generation ┆ is_updatab │
# │ log        ┆ ma         ┆ me       ┆ me        ┆   ┆ ycle       ┆ ed         ┆ _expressio ┆ le         │
# │ ---        ┆ ---        ┆ ---      ┆ ---       ┆   ┆ ---        ┆ ---        ┆ n          ┆ ---        │
# │ str        ┆ str        ┆ str      ┆ str       ┆   ┆ i32        ┆ i32        ┆ ---        ┆ i32        │
# │            ┆            ┆          ┆           ┆   ┆            ┆            ┆ i32        ┆            │
# ╞════════════╪════════════╪══════════╪═══════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ my_databas ┆ main       ┆ customer ┆ customer_ ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆ id        ┆   ┆            ┆            ┆            ┆            │
# │ my_databas ┆ main       ┆ customer ┆ first_nam ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆ e         ┆   ┆            ┆            ┆            ┆            │
# │ my_databas ┆ main       ┆ customer ┆ last_name ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆           ┆   ┆            ┆            ┆            ┆            │
# │ my_databas ┆ main       ┆ customer ┆ email     ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆           ┆   ┆            ┆            ┆            ┆            │
# │ …          ┆ …          ┆ …        ┆ …         ┆ … ┆ …          ┆ …          ┆ …          ┆ …          │
# │ my_databas ┆ main       ┆ customer ┆ customer_ ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆ segment   ┆   ┆            ┆            ┆            ┆            │
# │ my_databas ┆ main       ┆ customer ┆ total_ord ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆ ers       ┆   ┆            ┆            ┆            ┆            │
# │ my_databas ┆ main       ┆ customer ┆ total_spe ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆ nt        ┆   ┆            ┆            ┆            ┆            │
# │ my_databas ┆ main       ┆ customer ┆ is_active ┆ … ┆ null       ┆ null       ┆ null       ┆ null       │
# │ e          ┆            ┆ s        ┆           ┆   ┆            ┆            ┆            ┆            │
# └────────────┴────────────┴──────────┴───────────┴───┴────────────┴────────────┴────────────┴────────────┘
